# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra

# %%
data = pd.read_csv('../datasets/unemployment.csv')
data.head()

# keep: district code, district name, gender, demand_occupation, number
# Out:
#    Year    Month  District Code District Name  Neighborhood Code  \
# 0  2017  January              1  Ciutat Vella                  1
# 1  2017  January              1  Ciutat Vella                  2
# 2  2017  January              1  Ciutat Vella                  3
# 3  2017  January              1  Ciutat Vella                  4
# 4  2017  January              2      Eixample                  5
#
#                        Neighborhood Name Gender      Demand_occupation  Number
# 0                               el Raval   Male  Registered unemployed    2107
# 1                         el Barri Gòtic   Male  Registered unemployed     538
# 2                         la Barceloneta   Male  Registered unemployed     537
# 3  Sant Pere, Santa Caterina i la Ribera   Male  Registered unemployed     741
# 4                          el Fort Pienc   Male  Registered unemployed     630

# %%
data.info() # non-null data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14208 entries, 0 to 14207
# Data columns (total 9 columns):
# Year                 14208 non-null int64
# Month                14208 non-null object
# District Code        14208 non-null int64
# District Name        14208 non-null object
# Neighborhood Code    14208 non-null int64
# Neighborhood Name    14208 non-null object
# Gender               14208 non-null object
# Demand_occupation    14208 non-null object
# Number               14208 non-null int64
# dtypes: int64(4), object(5)
# memory usage: 999.1+ KB

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'District Code', 'District Name', 'Neighborhood Code',
#        'Neighborhood Name', 'Gender', 'Demand_occupation', 'Number'],
#       dtype='object')

# %%
#filtered = data[['Year', 'Month', 'District Code', 'District Name', 'Gender', 'Demand_occupation', 'Number']]

# %%
#filtered by year

# %%
filtered = data.loc[data['Year'] == 2017, 
                    ['Year', 'Month', 'District Code', 'District Name', 'Gender', 'Demand_occupation', 'Number']]

# %%
#filtered by demand_occupation

# %%
filtered = filtered.loc[filtered['Demand_occupation'] == 'Registered unemployed', 
                    ['Year', 'Month', 'District Code', 'District Name', 'Gender', 'Demand_occupation', 'Number']]

# %%
filtered
# Out:
#       Year     Month  District Code District Name  Gender  \
# 0     2017   January              1  Ciutat Vella    Male
# 1     2017   January              1  Ciutat Vella    Male
# 2     2017   January              1  Ciutat Vella    Male
# 3     2017   January              1  Ciutat Vella    Male
# 4     2017   January              2      Eixample    Male
# ...    ...       ...            ...           ...     ...
# 3473  2017  December             10    Sant Martí  Female
# 3474  2017  December             10    Sant Martí  Female
# 3475  2017  December             10    Sant Martí  Female
# 3476  2017  December             10    Sant Martí  Female
# 3477  2017  December             99     No consta  Female
#
#           Demand_occupation  Number
# 0     Registered unemployed    2107
# 1     Registered unemployed     538
# 2     Registered unemployed     537
# 3     Registered unemployed     741
# 4     Registered unemployed     630
# ...                     ...     ...
# 3473  Registered unemployed     800
# 3474  Registered unemployed     560
# 3475  Registered unemployed     797
# 3476  Registered unemployed     904
# 3477  Registered unemployed       3
#
# [1776 rows x 7 columns]

# %%
aggregated = filtered.groupby(by=
                              ['Year','District Name','District Code', 'Gender', 'Demand_occupation'], 
                              as_index =False ).agg({'Number':np.sum})

aggregated.head(25)
# Out:
#     Year        District Name  District Code  Gender      Demand_occupation  \
# 0   2017         Ciutat Vella              1  Female  Registered unemployed
# 1   2017         Ciutat Vella              1    Male  Registered unemployed
# 2   2017             Eixample              2  Female  Registered unemployed
# 3   2017             Eixample              2    Male  Registered unemployed
# 4   2017               Gràcia              6  Female  Registered unemployed
# 5   2017               Gràcia              6    Male  Registered unemployed
# 6   2017       Horta-Guinardó              7  Female  Registered unemployed
# 7   2017       Horta-Guinardó              7    Male  Registered unemployed
# 8   2017            Les Corts              4  Female  Registered unemployed
# 9   2017            Les Corts              4    Male  Registered unemployed
# 10  2017            No consta             99  Female  Registered unemployed
# 11  2017            No consta             99    Male  Registered unemployed
# 12  2017           Nou Barris              8  Female  Registered unemployed
# 13  2017           Nou Barris              8    Male  Registered unemployed
# 14  2017          Sant Andreu              9  Female  Registered unemployed
# 15  2017          Sant Andreu              9    Male  Registered unemployed
# 16  2017           Sant Martí             10  Female  Registered unemployed
# 17  2017           Sant Martí             10    Male  Registered unemployed
# 18  2017       Sants-Montjuïc              3  Female  Registered unemployed
# 19  2017       Sants-Montjuïc              3    Male  Registered unemployed
# 20  2017  Sarrià-Sant Gervasi              5  Female  Registered unemployed
# 21  2017  Sarrià-Sant Gervasi              5    Male  Registered unemployed
#
#     Number
# 0    35965
# 1    44154
# 2    65116
# 3    55819
# 4    32402
# 5    25725
# 6    53690
# 7    43663
# 8    19445
# 9    15084
# 10      50
# 11      38
# 12   66319
# 13   56402
# 14   51142
# 15   38810
# 16   78795
# 17   65192
# 18   58722
# 19   48838
# 20   23470
# 21   19055

# %%
aggregated.shape
# Out:
# (22, 6)

# %%
unemployed = aggregated.rename(columns={"Number" : "Reg_unemployed 2017"})

# %%
unemployed = unemployed[['District Name','District Code', 'Gender','Reg_unemployed 2017']]

# %%
unemployed
# Out:
#           District Name  District Code  Gender  Reg_unemployed 2017
# 0          Ciutat Vella              1  Female                35965
# 1          Ciutat Vella              1    Male                44154
# 2              Eixample              2  Female                65116
# 3              Eixample              2    Male                55819
# 4                Gràcia              6  Female                32402
# 5                Gràcia              6    Male                25725
# 6        Horta-Guinardó              7  Female                53690
# 7        Horta-Guinardó              7    Male                43663
# 8             Les Corts              4  Female                19445
# 9             Les Corts              4    Male                15084
# 10            No consta             99  Female                   50
# 11            No consta             99    Male                   38
# 12           Nou Barris              8  Female                66319
# 13           Nou Barris              8    Male                56402
# 14          Sant Andreu              9  Female                51142
# 15          Sant Andreu              9    Male                38810
# 16           Sant Martí             10  Female                78795
# 17           Sant Martí             10    Male                65192
# 18       Sants-Montjuïc              3  Female                58722
# 19       Sants-Montjuïc              3    Male                48838
# 20  Sarrià-Sant Gervasi              5  Female                23470
# 21  Sarrià-Sant Gervasi              5    Male                19055
